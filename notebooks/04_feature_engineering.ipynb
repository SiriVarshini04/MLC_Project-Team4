# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

df = pd.read_csv("../data/processed/aqi_clean.csv")

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Year"] = df["Date"].dt.year
df["Month"] = df["Date"].dt.month

# %%
X = df[["PM2.5", "PM10", "NO2", "SO2", "CO", "O3", "Month"]]
y = df["AQI"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
import joblib

joblib.dump(scaler, "../models/scaler.pkl")
# Out:
# ['../models/scaler.pkl']

# %%
X_scaled[:5]
# Out:
# array([[-2.66540371e-01, -1.93291289e-01, -4.12430271e-01,
#          8.12044180e-01, -1.83487791e-01,  4.91862529e+00,
#         -1.53475291e+00],
#        [-2.66540371e-01, -1.93291289e-01, -5.22190989e-01,
#          6.30336757e-01, -1.76052346e-01,  3.26103212e-03,
#         -1.53475291e+00],
#        [-2.66540371e-01, -1.93291289e-01, -3.65575893e-01,
#          8.96135318e-01,  2.26723506e+00, -1.63059450e-01,
#         -1.53475291e+00],
#        [-2.66540371e-01, -1.93291289e-01, -4.01150513e-01,
#          2.79859009e-01, -6.74948409e-02,  1.03251322e-01,
#         -1.53475291e+00],
#        [-2.66540371e-01, -1.93291289e-01, -2.73602485e-01,
#          1.49947453e+00,  2.96616694e+00,  2.63136786e-01,
#         -1.53475291e+00]])

# %%
## Feature Engineering Summary

- Extracted time-based features from Date
- Selected key pollutants based on EDA
- Scaled features using StandardScaler
- Prepared data for machine learning models
